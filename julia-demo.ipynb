# %%
using Pkg

Pkg.update()
Pkg.add("Plots")
Pkg.add("SymPy")
Pkg.add("Roots")
Pkg.add("ForwardDiff")
Pkg.add("ImplicitEquations")
# Out:
#   Updating registry at `C:\Users\Desktop\.julia\registries\General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
#  Resolving package versions...
#   Updating `C:\Users\Desktop\.julia\environments\v1.1\Project.toml`
#  [no changes]
#   Updating `C:\Users\Desktop\.julia\environments\v1.1\Manifest.toml`
#  [no changes]
#  Resolving package versions...
#  Installed PlotThemes ───────── v0.3.0
#  Installed Requires ─────────── v0.5.2
#  Installed RecipesBase ──────── v0.7.0
#  Installed Missings ─────────── v0.4.1
#  Installed FFMPEG ───────────── v0.2.2
#  Installed ColorTypes ───────── v0.8.0
#  Installed Plots ────────────── v0.26.0
#  Installed GR ───────────────── v0.40.0
#  Installed OrderedCollections ─ v1.1.0
#  Installed Showoff ──────────── v0.3.1
#  Installed Measures ─────────── v0.3.0
#  Installed SortingAlgorithms ── v0.3.1
#  Installed Contour ──────────── v0.5.1
#  Installed FixedPointNumbers ── v0.6.1
#  Installed StatsBase ────────── v0.31.0
# ...

# %%
using Plots

plot(sin, 0, 2pi)
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1186
